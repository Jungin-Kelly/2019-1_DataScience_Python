# %%
# '총 매출액' 100만원 단위로 나눠서 표시
data['총 매출액 (만원 단위)'] = (data['총 매출액']//1000000)*100
data['총 매출액 (만원 단위)']
#할인권 사용횟수 5단위로 나눠서 표시하기
data.loc[ df['할인권 사용 횟수'] <  5, '할인권 사용 횟수'] = 0
data.loc[ (df['할인권 사용 횟수'] >=  5) & (df['할인권 사용 횟수'] < 10)] = 5
data.loc[ (df['할인권 사용 횟수'] >=  10) & (df['할인권 사용 횟수'] < 15)] = 10
data.loc[ (df['할인권 사용 횟수'] >=  15) & (df['할인권 사용 횟수'] < 20)] = 15
data.loc[ (df['할인권 사용 횟수'] >=  20) & (df['할인권 사용 횟수'] < 25)] = 20
data.loc[ (df['할인권 사용 횟수'] >=  25) & (df['할인권 사용 횟수'] < 30)] = 25
data.loc[ df['할인권 사용 횟수'] >= 30 ] = 30
data['할인권 사용 횟수']
# '방문빈도 ' 10단위로 나눠서 표시하기 
data.loc[ df['방문빈도'] <  10, '방문빈도'] = 0
data.loc[ (df['방문빈도'] >=  10) & (df['방문빈도'] < 20)] =10
data.loc[ (df['방문빈도'] >=  20) & (df['방문빈도'] < 30)] = 20
data.loc[ (df['방문빈도'] >=  30) & (df['방문빈도'] < 40)] = 30
data.loc[ (df['방문빈도'] >=  40) & (df['방문빈도'] < 50)] = 40
data.loc[ (df['방문빈도'] >=  50) & (df['방문빈도'] < 60)] = 50
data.loc[ (df['방문빈도'] >=  60) & (df['방문빈도'] < 70)] = 60
data.loc[ (df['방문빈도'] >=  70) & (df['방문빈도'] < 80)] = 70
data.loc[ (df['방문빈도'] >=  80) & (df['방문빈도'] < 90)] = 80
data.loc[ (df['방문빈도'] >=  90) & (df['방문빈도'] < 100)] = 90
data.loc[ df['방문빈도'] >= 100 ] = 100
data['방문빈도']
# '1회 평균매출액' 10000원 미만은 0처리 나머지는 //10000 해서 만원 단위로 표시
data. loc[ df['1회 평균매출액']<10000,'1회 평균매출액'] = 0
data. loc[ df['1회 평균매출액'] >=10000,'1회 평균매출액'] = data['1회 평균매출액']//10000
# 값이 변해 있는 것을 확인 할 수 있음.
data['1회 평균매출액'][300:400]
# '총 매출액' 100만원 단위로 나눠서 표시
data['순수 매출액'] = (data['순수 매출액']//1000000)*100
# 값이 변한 것을 확인 할 수 있음.
data['순수 매출액']
# '거래기간' 30으로 나눠서 개월 수로 표시
data['거래기간'] = data['거래기간']//30
data['거래기간']
# '상품 품질', '상품 다양성 ', '가격 적절성'   시각화해서 가장 부족한 영역 찾기 -> 상품다양성이 그나마 낮음을 알 수 있음
from matplotlib import pyplot as plt 
plt.rcParams['font.family'] = 'Malgun Gothic'
x = ['상품 품질', '상품 다양성', '가격 적절성']
y = [data["상품 품질"].mean(), data["상품 다양성"].mean(), data["가격 적절성"].mean()]
plt.title('상품 평가 항목 별 평균',fontname ='Malgun Gothic')
plt.xlabel('평가항목',fontname ='Malgun Gothic')
plt.ylabel('평균 점수', fontname ='Malgun Gothic')
plt.bar(x, y, width = 0.7, color = 'pink')
plt.show()
# 친절성, 신속성, 책임성, 정확성, 전문성 시각화해서 가장 부족한 영역 찾기 -> 친절성이 그나마 낮음을 알 수 있음
from matplotlib import pyplot as plt 

plt.rcParams['font.family'] = 'Malgun Gothic'
x = ['친절성', '신속성', '책임성', '정확성', '전문성']
y = [data["친절성"].mean(), data["신속성"].mean(), data["책임성"].mean(), data["정확성"].mean(), data["전문성"].mean()]
plt.title('직원 평가 항목 별 평균', fontname ='Malgun Gothic')
plt.xlabel('평가항목', fontname ='Malgun Gothic')
plt.ylabel('평균 점수', fontname ='Malgun Gothic')
plt.bar(x, y, width = 0.7, color = 'orange')
plt.show()
# 매장 청결성' , '공간 편의성' , '시야  확보성' , '음향 적절성' 시각화해서 가장 부족한 영역 찾기 -> 시야 확보성이 그나마 낮음을 알 수 있음
from matplotlib import pyplot as plt 

plt.rcParams['font.family'] = 'Malgun Gothic'
x = ['매장 청결성' , '공간 편의성' , '시야  확보성' , '음향 적절성']
y = [data["매장 청결성"].mean(), data["공간 편의성"].mean(), data["시야 확보성"].mean(),data["음향 적절성"].mean()]
plt.title('매장평가 항목 별 평균')
plt.xlabel('평가항목')
plt.ylabel('평균 점수)', fontname ='Malgun Gothic')
plt.bar(x, y, width = 0.7, color = 'blue')
plt.show()
data.info()
customer = data.loc[:,['이탈여부', '총 매출액 (만원 단위)', '방문빈도', '1회 평균매출액', '순수 매출액', '할인권 사용 횟수', '고객등급', '구매유형', '클레임접수여부', '구매 카테고리 수', '거주지역', '성별', '고객 나이대', '거래기간', '할인민감여부', 'RFM 점수합계', '전체 만족도']]
customer
data['성별']
customer = df.loc[:,['이탈여부', '총 매출액', '방문빈도', '1회 평균매출액', '순수 매출액', '할인권 사용 횟수', '고객등급', '구매유형', '클레임접수여부', '구매 카테고리 수', '거주지역', '성별', '고객 나이대', '거래기간', '할인민감여부']]
customer
customer = df.loc[:,['이탈여부', '총 매출액', '방문빈도', '1회 평균매출액', '할인권 사용 횟수', '고객등급', '구매유형', '클레임접수여부', '구매 카테고리 수', '거주지역', '성별', '고객 나이대', '거래기간', '할인민감여부']]
customer
# '상품 만족도', '매장 만족도', '서비스 만족도', '상품 품질', '상품 다양성', '가격적절성', '매장 청결성','공간 편의성', '시야 확보성','음향 적절성', '친절성', '신속성', '책임성', '정확성', '전문성' 컬럼을 포함하는 evaluation 데이터 프레임 만들기
evaluation = df.loc[:,['상품 만족도', '매장 만족도', '서비스 만족도', '상품 품질', '상품 다양성', '가격적절성', '매장 청결성','공간 편의성', '시야 확보성','음향 적절성', '친절성', '신속성', '책임성', '정확성', '전문성']]
evaluation
# '상품 만족도', '매장 만족도', '서비스 만족도', '상품 품질', '상품 다양성', '가격 적절성', '매장 청결성','공간 편의성', '시야 확보성','음향 적절성', '친절성', '신속성', '책임성', '정확성', '전문성' 컬럼을 포함하는 evaluation 데이터 프레임 만들기
evaluation = df.loc[:,['상품 만족도', '매장 만족도', '서비스 만족도', '상품 품질', '상품 다양성', '가격 적절성', '매장 청결성','공간 편의성', '시야 확보성','음향 적절성', '친절성', '신속성', '책임성', '정확성', '전문성']]
evaluation
# 10. groupby 함수로 나타내기
# 친절성, 신속성, 책임성, 정확성, 전문성 시각화해서 가장 부족한 영역 찾기 -> 친절성이 그나마 낮음을 알 수 있음
from matplotlib import pyplot as plt 

plt.rcParams['font.family'] = 'Malgun Gothic'
x = ['친절성', '신속성', '책임성', '정확성', '전문성']
y = [data["친절성"].mean(), data["신속성"].mean(), data["책임성"].mean(), data["정확성"].mean(), data["전문성"].mean()]
plt.title('직원 평가 항목 별 평균', fontname ='Malgun Gothic')
plt.xlabel('평가항목', fontname ='Malgun Gothic')
plt.ylabel('평균 점수', fontname ='Malgun Gothic')
plt.bar(x, y, width = 0.7, color = 'orange')
plt.show()
[data["친절성"].mean(), data["신속성"].mean(), data["책임성"].mean(), data["정확성"].mean(), data["전문성"].mean()
# 친절성, 신속성, 책임성, 정확성, 전문성 시각화해서 가장 부족한 영역 찾기 -> 친절성이 그나마 낮음을 알 수 있음
from matplotlib import pyplot as plt 

plt.rcParams['font.family'] = 'Malgun Gothic'
x = ['친절성', '신속성', '책임성', '정확성', '전문성']
y = [data["친절성"].mean(), data["신속성"].mean(), data["책임성"].mean(), data["정확성"].mean(), data["전문성"].mean()]
plt.title('직원 평가 항목 별 평균', fontname ='Malgun Gothic')
plt.xlabel('평가항목', fontname ='Malgun Gothic')
plt.ylabel('평균 점수', fontname ='Malgun Gothic')
plt.bar(x, y, width = 0.7, color = 'orange')
plt.show()
data["친절성"].mean(), data["신속성"].mean(), data["책임성"].mean(), data["정확성"].mean(), data["전문성"].mean()
# 매장 청결성' , '공간 편의성' , '시야  확보성' , '음향 적절성' 시각화해서 가장 부족한 영역 찾기 -> 시야 확보성이 그나마 낮음을 알 수 있음
from matplotlib import pyplot as plt 

plt.rcParams['font.family'] = 'Malgun Gothic'
x = ['매장 청결성' , '공간 편의성' , '시야  확보성' , '음향 적절성']
y = [data["매장 청결성"].mean(), data["공간 편의성"].mean(), data["시야 확보성"].mean(),data["음향 적절성"].mean()]
plt.title('매장평가 항목 별 평균')
plt.xlabel('평가항목')
plt.ylabel('평균 점수)', fontname ='Malgun Gothic')
plt.bar(x, y, width = 0.7, color = 'blue')
plt.show()
data["매장 청결성"].mean(), data["공간 편의성"].mean(), data["시야 확보성"].mean(),data["음향 적절성"].mean()
# '상품 품질', '상품 다양성 ', '가격 적절성'   시각화해서 가장 부족한 영역 찾기 -> 상품다양성이 그나마 낮음을 알 수 있음
from matplotlib import pyplot as plt 
plt.rcParams['font.family'] = 'Malgun Gothic'
x = ['상품 품질', '상품 다양성', '가격 적절성']
y = [data["상품 품질"].mean(), data["상품 다양성"].mean(), data["가격 적절성"].mean()]
plt.title('상품 평가 항목 별 평균',fontname ='Malgun Gothic')
plt.xlabel('평가항목',fontname ='Malgun Gothic')
plt.ylabel('평균 점수', fontname ='Malgun Gothic')
plt.bar(x, y, width = 0.7, color = 'pink')
plt.show()
# '상품 품질', '상품 다양성 ', '가격 적절성'   시각화해서 가장 부족한 영역 찾기 -> 상품다양성이 그나마 낮음을 알 수 있음
from matplotlib import pyplot as plt 
plt.rcParams['font.family'] = 'Malgun Gothic'
x = ['상품 품질', '상품 다양성', '가격 적절성']
y = [data["상품 품질"].mean(), data["상품 다양성"].mean(), data["가격 적절성"].mean()]
plt.title('상품 평가 항목 별 평균',fontname ='Malgun Gothic')
plt.xlabel('평가항목',fontname ='Malgun Gothic')
plt.ylabel('평균 점수', fontname ='Malgun Gothic')
plt.bar(x, y, width = 0.7, color = 'pink')
plt.show()
data["상품 품질"].mean(), data["상품 다양성"].mean(), data["가격 적절성"].mean()
# '이탈여부'를 기준으로 그룹으로 나눠 표현하기
# '이탈여부'를 기준으로 그룹으로 나눠 표현하기
customer.groupby("이탈여부").mean()
# '고객등급'를 기준으로 그룹으로 나눠 표현하기
customer.groupby("고객등급").mean()
df["고객등급"]
# '고객 나이대'를 기준으로 그룹으로 나눠 표현하기
customer.groupby("고객 나이대").mean()
customer.groupby(['이탈여부','고객 나이대'])['총 출액'].sum().sort_values()
customer.groupby(['이탈여부','고객 나이대'])['총 매출액'].sum().sort_values()
customer.corr()
# cutomer 데이터 프레임 속 데이터들의 상관관계 보기
customer.corr()
# evaluation 데이터 프레임 속 데이터들의 상관관계 보기
evaluation.corr()
# 이탈한 고객 자료만 추출하기
# 이탈한 고객 자료만 추출하기
current = customer[customer.이탈여부 == '0']
current
# 이탈한 고객 자료만 추출하기
current = customer[customer.이탈여부 == '1']
current
# 이탈한 고객 자료만 추출하기
current = customer[customer.성별 == '1']
current
# customer 데이터 프레임 중 '이탈여부'가 0인 현재 고객 구하기 
current = customer.loc[df.이탈여부 == 0]
current
# customer 데이터 프레임 중 '이탈여부'가 0인 현재 고객만 추출하기
current = customer.loc[df.이탈여부 == 0]
current
# customer 데이터 프레임 중 '이탈여부'가 1인 이탈 고객만 추출하기
xcurrent = customer.loc[df.이탈여부 == 1]
xcurrent
import seaborn as sns
plt.figure(figsize=(10,10))
sns.heatmap(data = customer.corr(), annot = True, fnt = '.5f', linewidths=.5, cmap = 'Reds')
import seaborn as sns
plt.figure(figsize=(10,10))
sns.heatmap(data = customer.corr(), annot = True, linewidths=.5, cmap = 'Reds')
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(10,10))
sns.heatmap(data = customer.corr(), annot = True, linewidths=.5, cmap = 'Reds')
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(10,10))
sns.heatmap(data = current.corr(), annot = True, linewidths=.5, cmap = 'Reds')
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(10,10))
sns.heatmap(data = evaluation.corr(), annot = True, linewidths=.5, cmap = 'Reds')
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(10,10))
sns.heatmap(data = customer.corr(), annot = True, linewidths=.5, cmap = 'Greens')
sns.countplot(x="고객등급", data=df)
plt.show()
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.countplot(x="고객등급", data=customer)
plt.show()
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.countplot(x="구매유형", data=customer)
plt.show()
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.countplot(x="구매유형", data=customer)
plt.title('전체 고객의 구매 유형', fontname ='Malgun Gothic')
plt.xlabel('구매유형', fontname ='Malgun Gothic')
plt.ylabel('count', fontname ='Malgun Gothic')
plt.show()
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.countplot(x="구매유형", data=customer, grid = True)
plt.title('전체 고객의 구매 유형', fontname ='Malgun Gothic')
plt.xlabel('구매유형', fontname ='Malgun Gothic')
plt.ylabel('count', fontname ='Malgun Gothic')
plt.show()
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.countplot(x="구매유형", data=customer, grids=True)
plt.title('전체 고객의 구매 유형', fontname ='Malgun Gothic')
plt.xlabel('구매유형', fontname ='Malgun Gothic')
plt.ylabel('count', fontname ='Malgun Gothic')
plt.show()
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.countplot(x="구매유형", data=customer)
plt.title('전체 고객의 구매 유형', fontname ='Malgun Gothic')
plt.xlabel('구매유형', fontname ='Malgun Gothic')
plt.ylabel('count', fontname ='Malgun Gothic')
plt.show()
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.countplot(x="구매유형", data=current)
plt.title('현재 고객의 구매 유형', fontname ='Malgun Gothic')
plt.xlabel('구매유형', fontname ='Malgun Gothic')
plt.ylabel('count', fontname ='Malgun Gothic')
plt.show()
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.countplot(x="구매유형", data=xcurrent)
plt.title('이탈 고객의 구매 유형', fontname ='Malgun Gothic')
plt.xlabel('구매유형', fontname ='Malgun Gothic')
plt.ylabel('count', fontname ='Malgun Gothic')
plt.show()
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

a = plt.subplots()
a = sns.countplot('고객 나이대', hue='성별', data = customer)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

a = plt.subplots()
a = sns.countplot('고객 나이대', hue='성별', data = customer)
a.set_title('고객 나이대 별 성별')
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.family'] = 'Malgun Gothic'
a = plt.subplots()
a = sns.countplot('고객 나이대', hue='성별', data = customer)
a.set_title('고객 나이대 별 성별')
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.family'] = 'Malgun Gothic'
a = plt.subplots()
a = sns.countplot('고객 나이대', hue='성별', data = customer)
a.set_title('전체 고객 나이대 별 성별')
# 현재 고객 나이대 별 성별 시각화 하기
plt.rcParams['font.family'] = 'Malgun Gothic'
a = plt.subplots()
a = sns.countplot('고객 나이대', hue='성별', data = current)
a.set_title('현재 고객 나이대 별 성별')
# 현재 고객 나이대 별 성별 시각화 하기
plt.rcParams['font.family'] = 'Malgun Gothic'
a = plt.subplots()
a = sns.countplot('고객 나이대', hue='성별', data =xcurrent)
a.set_title('현재 고객 나이대 별 성별')
# 이탈 고객 나이대 별 성별 시각화 하기
plt.rcParams['font.family'] = 'Malgun Gothic'
a = plt.subplots()
a = sns.countplot('고객 나이대', hue='성별', data =xcurrent)
a.set_title('이탈 고객 나이대 별 성별')
x = customer['방문빈도']
y = customer['총 매출액']
z = np.polyfit(x,y,1)
p = np.poly1d(z)
pylab.plot(x,y, 'o', color = 'yellow')
pylab.plot(x,p(x),"r--")
import numpy as np
import matplot.pylab as pylab
x = customer['방문빈도']
y = customer['총 매출액']
z = np.polyfit(x,y,1)
p = np.poly1d(z)
pylab.plot(x,y, 'o', color = 'yellow')
pylab.plot(x,p(x),"r--")
import numpy as np
import matplotlib.pylab as pylab
x = customer['방문빈도']
y = customer['총 매출액']
z = np.polyfit(x,y,1)
p = np.poly1d(z)
pylab.plot(x,y, 'o', color = 'yellow')
pylab.plot(x,p(x),"r--")
import numpy as np
import matplotlib.pylab as pylab
x = customer['방문빈도']
y = customer['총 매출액']
z = np.polyfit(x,y,1)
p = np.poly1d(z)
pylab.plot(x,y, 'o', color = 'orange')
pylab.plot(x,p(x),"r--")
# customer 상관관계 분석에서 높은 상관관계를 보인 '총 매출액'과 '방문빈도'의 산점도와 추세선 그리기 
import numpy as np
import matplotlib.pylab as pylab
plt.rcParams['font.family'] = 'Malgun Gothic'
x = customer['방문빈도']
y = customer['총 매출액']
z = np.polyfit(x,y,1)
p = np.poly1d(z)
pylab.plot(x,y, 'o', color = 'orange')
pylab.plot(x,p(x),"r--")
# 고객 이탈여부와 '상품 만족도', '매장 만족도', '서비스 만족도' 를 가지고 cne(customer and evaluation) 데이터 프레임 만들기
cne = df.loc[:,['이탈여부'.'상품 만족도', '매장 만족도', '서비스 만족도' ]]
cne
# 고객 이탈여부와 '상품 만족도', '매장 만족도', '서비스 만족도' 를 가지고 cne(customer and evaluation) 데이터 프레임 만들기
cne = df.loc[:,['이탈여부','상품 만족도', '매장 만족도', '서비스 만족도' ]]
cne
# cne 데이터 프레임 속 데이터들의 상관관계 보기
cne.corr()
# evaluation 데이터들의 상관관계를 히트맵으로 나타내기
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(10,10))
sns.heatmap(data = cne.corr(), annot = True, linewidths=.5, cmap = 'Blues')
# evaluation 상관관계 분석에서 높은 상관관계를 보인 '정확성'과 '전문성'의 산점도와 추세선 그리기 
import numpy as np
import matplotlib.pylab as pylab
plt.rcParams['font.family'] = 'Malgun Gothic'
x = evaluation['정확성']
y = evaluation['전문성']
z = np.polyfit(x,y,1)
p = np.poly1d(z)
pylab.plot(x,y, 'o', color = 'orange')
pylab.plot(x,p(x),"r--")
# Out:
#   File "<ipython-input-1-c4719b5e963c>", line 98
#     from matplotlib import pyplot as plt
#        ^
# SyntaxError: invalid syntax
